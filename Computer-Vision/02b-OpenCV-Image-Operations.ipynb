# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # Opening Images in Notebook

# %%
pic = cv2.imread('../meta/00-puppy.jpg')
print(type(pic))
plt.imshow(pic)
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# > Matplotlib -> RGB
#
# > OpenCv -> BGR

# %%
pic = cv2.imread('../meta/00-puppy.jpg')
pic = cv2.cvtColor(pic, cv2.COLOR_BGR2RGB)
plt.imshow(pic)

# %% [markdown]
# # Grayscaling

# %%
pic_gray = cv2.imread('../meta/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)
print(pic_gray.shape)
plt.imshow(pic_gray, cmap='gray')
# Out:
# (1300, 1950)

# %% [markdown]
# # Resizing

# %%
pic_resized = cv2.resize(pic, (975,650)) # w, h
print(pic_resized.shape) # r, c (h, w)
plt.imshow(pic_resized)
# Out:
# (650, 975, 3)

# %% [markdown]
# # Flipping

# %%
plt.imshow(cv2.flip(pic, 0))

# %%
plt.imshow(cv2.flip(pic, 1))

# %%
plt.imshow(cv2.flip(pic, -1))

# %% [markdown]
# # Custom Axis

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.imshow(pic)
